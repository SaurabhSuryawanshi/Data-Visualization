# %%
import seaborn as sb
import pandas as pd
import numpy as np
import matplotlib.pyplot as pp

# %%
sb.get_dataset_names()
#displaying the datasets of sb repository
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
ds1=sb.load_dataset('flights')

# %%
ds1
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
ds2=sb.load_dataset('car_crashes')
#loading a car crashes dataset

# %%
ds2
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
ds2.plot.bar()
#plotting a bar chart
# Out:
# <Axes: >

# %%
ds2['alcohol'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
ds2['speeding'].plot.hist()
#showing the dataset in histogram of particular data column
# Out:
# <Axes: ylabel='Frequency'>

# %%
ds2.plot(kind='hist',stacked=True,bins=20,figsize=(5,10),title='DV of car crashes')
#data stacked above one another
# Out:
# <Axes: title={'center': 'DV of car crashes'}, ylabel='Frequency'>

# %%
ds2.plot()
#plotting the overall data in one chart
# Out:
# <Axes: >

# %%
ds2.hist(figsize=(10,15),color='#119900',alpha=.5,sharex=False)
#here you can see the frequency and count of all the data column wise
# Out:
# array([[<Axes: title={'center': 'total'}>,
#         <Axes: title={'center': 'speeding'}>,
#         <Axes: title={'center': 'alcohol'}>],
#        [<Axes: title={'center': 'not_distracted'}>,
#         <Axes: title={'center': 'no_previous'}>,
#         <Axes: title={'center': 'ins_premium'}>],
#        [<Axes: title={'center': 'ins_losses'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
ds2.plot.scatter(x='alcohol',y='speeding')
#scattering the data of variables who were speeding while intoxicated
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
ds2.plot.scatter(x='alcohol',y='speeding',c='not_distracted')
#more the alcohol intake higher the spedding so more the distraction
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
ds2.plot.scatter(x='alcohol',y='speeding',c='not_distracted',label='do not drink&drive',s=30)
#just labelling it and drawing a size to the variables
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
ds2.plot.hexbin(x='alcohol',y='speeding',gridsize=30,label='HexaShape')
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
ds2.plot(kind='pie', y='speeding')
#plotting a pie chart for spedding value
# Out:
# <Axes: ylabel='speeding'>

# %%
ds2.plot(kind='pie',y='alcohol')
#plotting a pie chart for alcohol
# Out:
# <Axes: ylabel='alcohol'>

# %%
ds2
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
ds2.iloc[0:15].plot.pie(y='alcohol',figsize=(5,10),autopct='%.2f')
#displaying the particular values by locking
# Out:
# <Axes: ylabel='alcohol'>

# %%
pd.plotting.scatter_matrix(ds2,figsize=(10,10))
# Out:
# array([[<Axes: xlabel='total', ylabel='total'>,
#         <Axes: xlabel='speeding', ylabel='total'>,
#         <Axes: xlabel='alcohol', ylabel='total'>,
#         <Axes: xlabel='not_distracted', ylabel='total'>,
#         <Axes: xlabel='no_previous', ylabel='total'>,
#         <Axes: xlabel='ins_premium', ylabel='total'>,
#         <Axes: xlabel='ins_losses', ylabel='total'>],
#        [<Axes: xlabel='total', ylabel='speeding'>,
#         <Axes: xlabel='speeding', ylabel='speeding'>,
#         <Axes: xlabel='alcohol', ylabel='speeding'>,
#         <Axes: xlabel='not_distracted', ylabel='speeding'>,
#         <Axes: xlabel='no_previous', ylabel='speeding'>,
#         <Axes: xlabel='ins_premium', ylabel='speeding'>,
#         <Axes: xlabel='ins_losses', ylabel='speeding'>],
#        [<Axes: xlabel='total', ylabel='alcohol'>,
#         <Axes: xlabel='speeding', ylabel='alcohol'>,
#         <Axes: xlabel='alcohol', ylabel='alcohol'>,
# ...

# %%
pd.plotting.scatter_matrix(ds2,figsize=(10,10),diagonal='kde')
#plotting the graph with kernel density estimator.
# Out:
# array([[<Axes: xlabel='total', ylabel='total'>,
#         <Axes: xlabel='speeding', ylabel='total'>,
#         <Axes: xlabel='alcohol', ylabel='total'>,
#         <Axes: xlabel='not_distracted', ylabel='total'>,
#         <Axes: xlabel='no_previous', ylabel='total'>,
#         <Axes: xlabel='ins_premium', ylabel='total'>,
#         <Axes: xlabel='ins_losses', ylabel='total'>],
#        [<Axes: xlabel='total', ylabel='speeding'>,
#         <Axes: xlabel='speeding', ylabel='speeding'>,
#         <Axes: xlabel='alcohol', ylabel='speeding'>,
#         <Axes: xlabel='not_distracted', ylabel='speeding'>,
#         <Axes: xlabel='no_previous', ylabel='speeding'>,
#         <Axes: xlabel='ins_premium', ylabel='speeding'>,
#         <Axes: xlabel='ins_losses', ylabel='speeding'>],
#        [<Axes: xlabel='total', ylabel='alcohol'>,
#         <Axes: xlabel='speeding', ylabel='alcohol'>,
#         <Axes: xlabel='alcohol', ylabel='alcohol'>,
# ...

# %%
# !pip install plotly

# %%
# !pip install cufflinks

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as plt
import cufflinks as cl

# %%
py.offline.init_notebook_mode(connected=True)
cl.go_offline()
#going offline with plotly to make charts interactive without connection
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
ds2.iplot()

# %%
ds2.iplot(x='ins_premium',y='ins_losses',kind='hist')

# %%
ds2.iplot(kind='box')
#box plot to find out outliers

# %%
ds2.iplot(x='alcohol',y='speeding',z='ins_losses',kind='scatter3d')
#3d plotting of values

# %%
ds2.iplot(x='alcohol',y='speeding',z='ins_losses',kind='bubble3d',size='speeding')
#3d bubble plotting
